# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib
import tensorflow as tf

from matplotlib import pyplot as plt

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

# %%
ts.head(5)
# Out:
# 2000-01-01    0.062367
# 2000-01-02   -0.411098
# 2000-01-03   -0.505511
# 2000-01-04    0.657171
# 2000-01-05   -0.832168
# Freq: D, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])
df = df.cumsum()

# %%
df.head(5)
# Out:
#                    A         B         C         D
# 2000-01-01 -0.380589 -0.692990  0.877071 -0.179062
# 2000-01-02 -0.353527 -2.084412  0.383228 -1.573352
# 2000-01-03  0.880079  0.405972 -1.126972 -2.022924
# 2000-01-04  0.742900  0.869827 -0.282193 -0.879959
# 2000-01-05  1.171548  0.620291  0.363965 -0.881903

# %%
plt.figure(); df.plot(); plt.legend(loc='best')
